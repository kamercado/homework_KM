# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lng_list = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        lat_lng_list.append(lat_lng)


# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# #### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/'
city_weather = {}
city_counter = 0
for city in cities:
    query = f"{url}weather?q={city}&appid={api_key}"
    response = requests.get(query).json()
    city_counter += 1
    print(f'{city_counter} {city}')
# Out:
# 1 thompson
# 2 aleksandrovsk-sakhalinskiy
# 3 mataura
# 4 bluff
# 5 algeciras
# 6 laramie
# 7 ushuaia
# 8 balkanabat
# 9 san cristobal
# 10 labuhan
# 11 namibe
# 12 codrington
# 13 payakumbuh
# 14 singaparna
# 15 ugoofaaru
# 16 santa cruz
# 17 sao filipe
# 18 west bay
# 19 jaru
# 20 hermanus
# 21 kodiak
# 22 new ulm
# 23 palabuhanratu
# 24 kavieng
# 25 punta arenas
# 26 panormos
# 27 tilichiki
# 28 tasiilaq
# 29 odweyne
# 30 flinders
# 31 pafos
# 32 arona
# 33 rikitea
# 34 albany
# 35 rocha
# 36 lebu
# 37 fortuna
# 38 nouadhibou
# 39 east london
# 40 bethel
# 41 clyde river
# 42 vestmannaeyjar
# 43 butaritari
# 44 belushya guba
# 45 severo-kurilsk
# 46 mys shmidta
# 47 geraldton
# 48 amderma
# 49 leningradskiy
# 50 batagay
# 51 qaqortoq
# 52 ilulissat
# 53 itarema
# 54 wanning
# 55 savinka
# 56 hamilton
# 57 egvekinot
# 58 kaitangata
# 59 taolanaro
# 60 rayadrug
# 61 hovd
# 62 port macquarie
# 63 nikolskoye
# 64 falealupo
# 65 pevek
# 66 maniwaki
# 67 kudahuvadhoo
# 68 hobart
# 69 yomitan
# 70 tkvarcheli
# 71 saint-philippe
# 72 vetlanda
# 73 busselton
# 74 nizhneyansk
# 75 saskylakh
# 76 lensk
# 77 jamestown
# 78 oktyabrskiy
# 79 tuktoyaktuk
# 80 laguna
# 81 saldanha
# 82 bogande
# 83 louisbourg
# 84 airai
# 85 cap malheureux
# 86 sibu
# 87 kinkala
# 88 pochutla
# 89 illoqqortoormiut
# 90 arraial do cabo
# 91 bredasdorp
# 92 biak
# 93 qaanaaq
# 94 nanortalik
# 95 busca
# 96 pisco
# 97 chokurdakh
# 98 gorontalo
# 99 ponta do sol
# 100 prince george
# 101 takoradi
# 102 mirnyy
# 103 longyearbyen
# 104 cape town
# 105 port hedland
# 106 san patricio
# 107 tall kayf
# 108 eureka
# 109 kutum
# 110 halalo
# 111 najran
# 112 aasiaat
# 113 koungou
# 114 lady frere
# 115 grand gaube
# 116 chapais
# 117 lashio
# 118 andros town
# 119 roma
# 120 xiongzhou
# 121 sentyabrskiy
# 122 asfi
# 123 fergus falls
# 124 nguiu
# 125 mahebourg
# 126 port alfred
# 127 victoria
# 128 mastic beach
# 129 conway
# 130 camacha
# 131 yar-sale
# 132 bengkulu
# 133 krasnovishersk
# 134 avarua
# 135 vyartsilya
# 136 carnarvon
# 137 puerto ayora
# 138 nioro
# 139 luau
# 140 vaini
# 141 lagoa
# 142 knysna
# 143 khatanga
# 144 vangaindrano
# 145 barrow
# 146 puerto narino
# 147 ureki
# 148 lipin bor
# 149 muros
# 150 orel-izumrud
# 151 mar del plata
# 152 alyangula
# 153 valdivia
# 154 mitzic
# 155 kurumkan
# 156 pontes e lacerda
# 157 chuy
# 158 torbay
# 159 sorong
# 160 irtyshskiy
# 161 hermosillo
# 162 saint-augustin
# 163 mandiana
# 164 tiksi
# 165 kapaa
# 166 flin flon
# 167 dikson
# 168 kailua
# 169 oistins
# 170 boulsa
# 171 mount isa
# 172 narsaq
# 173 sergeyevka
# 174 alofi
# 175 husavik
# 176 hilo
# 177 sindand
# 178 miraflores
# 179 burns lake
# 180 kruisfontein
# 181 pindobacu
# 182 chama
# 183 port elizabeth
# 184 yelizovo
# 185 daxian
# 186 gueret
# 187 encheng
# 188 jinan
# 189 seka
# 190 muisne
# 191 tornio
# 192 grindavik
# 193 fraga
# 194 te anau
# 195 georgetown
# 196 constitucion
# 197 yellowknife
# 198 tungor
# 199 tucurui
# 200 nong phai
# 201 dakoro
# 202 asht
# 203 umm lajj
# 204 akdepe
# 205 ordu
# 206 saltillo
# 207 mayo
# 208 denia
# 209 walvis bay
# 210 bilma
# 211 tsihombe
# 212 cervo
# 213 talara
# 214 fairbanks
# 215 mogadishu
# 216 kawambwa
# 217 mujiayingzi
# 218 arrifes
# 219 ribeira grande
# 220 kizema
# 221 puerto rondon
# 222 phan thiet
# 223 le port
# 224 smithers
# 225 lata
# 226 cidreira
# 227 sembakung
# 228 coari
# 229 hobe sound
# 230 polyarnyy
# 231 ucluelet
# 232 valparaiso
# 233 gat
# 234 esso
# 235 rojhan
# 236 kenai
# 237 luanda
# 238 little current
# 239 ostersund
# 240 qasigiannguit
# 241 olinda
# 242 ancud
# 243 half moon bay
# 244 laukaa
# 245 slyudyanka
# 246 broome
# 247 bambanglipuro
# 248 san quintin
# 249 alenquer
# 250 coos bay
# 251 atuona
# 252 grand river south east
# 253 tautira
# 254 vila franca do campo
# 255 padang
# 256 vostok
# 257 provideniya
# 258 rantepao
# 259 new norfolk
# 260 molodizhne
# 261 turayf
# 262 lujan
# 263 lorengau
# 264 elliot
# 265 samusu
# 266 panacan
# 267 castro
# 268 noumea
# 269 malwan
# 270 dauriya
# 271 mocambique
# 272 eskhar
# 273 abay
# 274 fallon
# 275 mangochi
# 276 baruun-urt
# 277 berlevag
# 278 touros
# 279 barentsburg
# 280 dunedin
# 281 cabo san lucas
# 282 buraydah
# 283 saleaula
# 284 gumla
# 285 ahipara
# 286 ijaki
# 287 katsuura
# 288 saryagash
# 289 lasa
# 290 ayagoz
# 291 malakal
# 292 saint-esteve
# 293 mekhe
# 294 lesosibirsk
# 295 bandarbeyla
# 296 esperance
# 297 alice springs
# 298 mahaicony
# 299 saint george
# 300 labytnangi
# 301 karauzyak
# 302 octeville
# 303 hofn
# 304 hualmay
# 305 spirovo
# 306 deputatskiy
# 307 olafsvik
# 308 shibetsu
# 309 cam ranh
# 310 imbituba
# 311 soro
# 312 tumannyy
# 313 urumqi
# 314 bargal
# 315 mednogorsk
# 316 margate
# 317 baraboo
# 318 marcona
# 319 kropotkin
# 320 bilibino
# 321 faanui
# 322 khrebtovaya
# 323 xinzhou
# 324 aklavik
# 325 srivardhan
# 326 zaozerne
# 327 reinosa
# 328 upernavik
# 329 saint anthony
# 330 yerbogachen
# 331 mullaitivu
# 332 tynne
# 333 saint-pierre
# 334 gamba
# 335 iqaluit
# 336 souillac
# 337 cambridge
# 338 cherskiy
# 339 kasempa
# 340 jabiru
# 341 hauterive
# 342 beipiao
# 343 doctor juan leon mallorquin
# 344 berbera
# 345 hobyo
# 346 emerald
# 347 attawapiskat
# 348 puerto escondido
# 349 konevo
# 350 harer
# 351 norman wells
# 352 sambava
# 353 orsha
# 354 talcahuano
# 355 chumikan
# 356 paracuru
# 357 helong
# 358 bathsheba
# 359 tsuruoka
# 360 beroroha
# 361 rehoboth
# 362 mfou
# 363 acarau
# 364 port-cartier
# 365 tacna
# 366 upata
# 367 churapcha
# 368 mobile
# 369 kidal
# 370 praia da vitoria
# 371 isangel
# 372 vallenar
# 373 kiruna
# 374 jijiga
# 375 gizo
# 376 port blair
# 377 pandoh
# 378 majene
# 379 okhotsk
# 380 cascais
# 381 sitka
# 382 vidim
# 383 nemuro
# 384 huarmey
# 385 yenagoa
# 386 luderitz
# 387 urgut
# 388 zyryanskoye
# 389 tawkar
# 390 ca mau
# 391 hithadhoo
# 392 dalvik
# 393 saurimo
# 394 opuwo
# 395 kribi
# 396 kalmunai
# 397 visnes
# 398 atambua
# 399 wollongong
# 400 longlac
# 401 nome
# 402 council bluffs
# 403 aquidauana
# 404 papetoai
# 405 kununurra
# 406 aksarka
# 407 goya
# 408 champerico
# 409 tunxi
# 410 balatonszarszo
# 411 tukan
# 412 yulara
# 413 kavaratti
# 414 cine
# 415 ginir
# 416 sulphur
# 417 aswan
# 418 cartagena
# 419 kuching
# 420 teguldet
# 421 sao felix do xingu
# 422 tocopilla
# 423 quelimane
# 424 manbij
# 425 garden city
# 426 santa isabel do rio negro
# 427 nyurba
# 428 pangkalanbuun
# 429 gariaband
# 430 siocon
# 431 kamenka
# 432 saryshagan
# 433 hihifo
# 434 faya
# 435 terney
# 436 neiafu
# 437 el faiyum
# 438 maykain
# 439 marzuq
# 440 khammam
# 441 adrar
# 442 krumovgrad
# 443 zlobin
# 444 vredendal
# 445 talnakh
# 446 luoyang
# 447 alexandria
# 448 kondoa
# 449 vardo
# 450 bambous virieux
# 451 nurpur
# 452 sisimiut
# 453 buqayq
# 454 razole
# 455 leghorn
# 456 makakilo city
# 457 nishihara
# 458 coffs harbour
# 459 kamina
# 460 wewak
# 461 bairnsdale
# 462 bubaque
# 463 weinan
# 464 novomalorossiyskaya
# 465 waingapu
# 466 derzhavinsk
# 467 severomuysk
# 468 moerai
# 469 canaway
# 470 westport
# 471 joshimath
# 472 morros
# 473 srednekolymsk
# 474 yerofey pavlovich
# 475 antofagasta
# 476 vagur
# 477 abha
# 478 dingle
# 479 boddam
# 480 khandyga
# 481 freeport
# 482 illapel
# 483 zhangjiakou
# 484 esterhazy
# 485 palafrugell
# 486 keetmanshoop
# 487 wajima
# 488 kloulklubed
# 489 newcastle
# 490 kyzyl-suu
# 491 dori
# 492 yicheng
# 493 karratha
# 494 umzimvubu
# 495 lazaro cardenas
# 496 zhigansk
# 497 hasaki
# 498 dhidhdhoo
# 499 pilar
# 500 aysha
# 501 warqla
# 502 vaitape
# 503 klaebu
# 504 maniitsoq
# 505 tabukiniberu
# 506 umm durman
# 507 rio branco
# 508 roebourne
# 509 caucaia
# 510 pergamino
# 511 nortelandia
# 512 mulege
# 513 zyryanka
# 514 mantua
# 515 mareeba
# 516 stornoway
# 517 rocky mountain house
# 518 tezu
# 519 bhainsdehi
# 520 connersville
# 521 xichang
# 522 lompoc
# 523 burica
# 524 praya
# 525 sobolevo
# 526 the valley
# 527 los llanos de aridane
# 528 vila velha
# 529 colesberg
# 530 salalah
# 531 ulcinj
# 532 pangnirtung
# 533 mehamn
# 534 khani
# 535 kollam
# 536 sorvag
# 537 farmington
# 538 barcelos
# 539 sorland
# 540 great bend
# 541 camaqua
# 542 villefranche-de-rouergue
# 543 madanapalle
# 544 kalemie
# 545 lembang
# 546 ambunti
# 547 san policarpo
# 548 cayenne
# 549 naron
# 550 tashla
# 551 saint-prosper
# 552 les cayes
# 553 ler
# 554 camana
# 555 ipixuna
# 556 winchester
# 557 zharkent
# 558 zinder
# 559 kayes
# 560 glinka
# 561 tessalit
# 562 shambu
# 563 vestbygda
# 564 avera
# 565 havoysund
# 566 fort-shevchenko
# 567 mount gambier
# 568 paita
# 569 arman
# 570 dabat
# 571 tayoltita
# 572 naze
# 573 caravelas
# 574 poum
# 575 hami
# 576 marquette
# 577 karatau
# 578 nuevo progreso
# 579 rangapara
# 580 cluses
# 581 san ramon
# 582 kaka
# 583 portobelo
# 584 xai-xai
# 585 prince rupert
# 586 vanimo
# 587 ludvika
# 588 port-gentil
# 589 rungata
# 590 petrovac
# 591 kaspiyskiy
# 592 tashtyp
# 593 kieta
# 594 aloleng
# 595 richards bay
# 596 beringovskiy
# 597 balikpapan
# 598 nombre de dios
# 599 ostrovnoy
# 600 ramotswa
# 601 manggar
# 602 klaksvik
# 603 ekibastuz
# 604 port hardy
# 605 howard springs
# 606 metu
# 607 kegayli
# 608 conceicao da barra
# 609 kendallville
# 610 udachnyy
# 611 wang saphung
# 612 dahanu

# %%
# lists for lat and temp
lat = []
temp = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    query = f"{url}weather?q={city}&appid={api_key}"
    response = requests.get(query).json()
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-dba0aa274895> in <module>
#       7     query = f"{url}weather?q={city}&appid={api_key}"
#       8     response = requests.get(query).json()
# ----> 9     lat.append(response['coord']['lat'])
#      10     temp.append(response['main']['temp'])
#
# KeyError: 'coord'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city": cities,
    "lat": lat_lng_list
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#                          city                                       lat
# 0                    thompson   (62.51141397338864, -89.39641449709677)
# 1  aleksandrovsk-sakhalinskiy   (50.62880444176261, 141.64747970930313)
# 2                     mataura  (-48.61966430519722, -157.4716004665924)
# 3                       bluff  (-68.45041805517639, 170.42448980898348)
# 4                   algeciras    (11.42851198659585, 121.1264896950475)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
